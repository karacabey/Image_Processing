# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/img.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1100x736 at 0x7F34148A3290>

# %%
print(img.size)
# Out:
# 2428800

# %%
print(img.dtype)
# Out:
# uint8

# %%
print(img.shape)
# Out:
# (736, 1100, 3)

# %% [markdown]
# we have width, height and channel information by using "shape" function.
