# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/content/img.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1100x736 at 0x7F34148A37D0>

# %%
print(img.size)
# Out:
# 2428800

# %%
print(img.dtype)
# Out:
# uint8

# %%
print(img.shape)
# Out:
# (736, 1100, 3)

# %% [markdown]
# we have width, height and channel information by using "shape" function.

# %%
row = 256
col = 256
img1 = np.zeros((row,col))
img1[100:105,:] = 0.5
img1[:,100:105] = 1

# %%
plt.figure(figsize=(10,4))
plt.imshow(img1)
plt.show()

# %%
h = 512
w = 512
img2 = np.random.randint(255,size=(h,w,1),dtype=np.uint8)

cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F3413CE5290>
